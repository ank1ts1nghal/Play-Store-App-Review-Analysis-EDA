# %% [markdown]
# <a href="https://colab.research.google.com/github/ank1ts1nghal/Play-Store-App-Review-Analysis-EDA/blob/main/Play_Store_App_Review_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis (Exploratory Data Analysis)

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Ankit Singhal

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.

# %% [markdown]
# Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
# Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# ![google-play.gif](data:image/gif;base64,...)

# %% [markdown]
# In this EDA project, I will analyze the data from the Google Play Store provided to us in the form of two csv files. During the analysis, I utilized the Python programming language. This research represents my initial exploration into data analysis.
#
# The subject of investigation is the Google Play Store, which is home to a vast array of mobile applications. The ease of app creation and their potential for profitability have led to a significant surge in app development. Within this notebook, we aim to conduct a comprehensive analysis of the Android app market by examining a dataset encompassing over ten thousand apps from various categories. Our objective is to uncover valuable insights from the data that can inform strategies for driving growth and user retention.
#
# Let's delve into the dataset, which comprises two files:
#
# 1. playstore data.csv: This file contains comprehensive information about the applications available on Google Play. It encompasses 13 features that provide descriptive details about each app.
#
# 2. user_reviews.csv: This file contains a collection of 100 reviews for each app, sorted by helpfulness. The text of each review has undergone preprocessing and includes three additional features: Sentiment (Positive, Negative, or Neutral), Sentiment Polarity, and Sentiment Subjectivity.
#
# Before delving into the provided dataset, allow me to provide a brief explanation of Exploratory Data Analysis (EDA).

# %% [markdown]
# **Exploratory Data Analysis (EDA) :-**

# %% [markdown]
# Exploratory Data Analysis (EDA) is a crucial step in the data analysis process. It involves examining and visualizing the dataset to gain insights, discover patterns, and identify relationships between variables. Through EDA, we can uncover key characteristics of the data, such as its distribution, central tendencies, and variations. This exploration helps us understand the data's structure, identify any data quality issues or outliers, and guide us in selecting appropriate statistical techniques and models for further analysis. By employing various statistical and visualization techniques, EDA aids in formulating hypotheses, validating assumptions, and generating actionable insights that drive decision-making in data-driven projects. In summary, EDA serves as the foundation for a comprehensive understanding of the data, enabling us to extract meaningful information and drive meaningful conclusions.

# %% [markdown]
# Here are the general steps involved in Exploratory Data Analysis (EDA):
#
# 1. Data Collection: Gather the relevant dataset for analysis, which may come from various sources such as databases, files, or APIs.
#
# 2. Data Cleaning: Preprocess the data to handle missing values, outliers, and inconsistencies. This step involves techniques like data imputation, outlier detection, and handling categorical variables.
#
# 3. Data Exploration: Perform initial exploration by examining the dataset's structure, dimensions, and summary statistics. This includes checking the data types, understanding variable distributions, and identifying potential issues.
#
# 4. Univariate Analysis: Analyze individual variables to gain insights into their distributions, central tendencies, and variations. This involves plotting histograms, box plots, and computing summary statistics.
#
# 5. Bivariate Analysis: Explore relationships between pairs of variables to identify correlations, dependencies, or patterns. This includes scatter plots, correlation matrices, and grouped analysis.
#
# 6. Multivariate Analysis: Investigate interactions between multiple variables to uncover complex relationships or dependencies. Techniques like heatmaps, cluster analysis, or dimensionality reduction can be applied.
#
# 7. Feature Engineering: Create new features or transform existing ones based on domain knowledge and insights gained from the data analysis. This step aims to enhance predictive power or simplify the modeling process.
#
# 8. Visualization: Utilize various visualizations such as bar charts, line plots, scatter plots, or heatmaps to effectively communicate patterns and relationships in the data.
#
# 9. Statistical Analysis: Apply statistical techniques, such as hypothesis testing or regression analysis, to derive meaningful conclusions and validate assumptions.
#
# 10. Iterative Process: EDA is often an iterative process where insights from initial analyses lead to further exploration and refinement of hypotheses or models.
#
# 11. Documentation and Reporting: Summarize the findings, insights, and key takeaways from the EDA process. This documentation helps stakeholders understand the data and make informed decisions.
#
# We have to keep in mind that the specific steps and techniques employed in EDA may vary depending on the nature of the data and the objectives of the analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [link text](https://github.com/ank1ts1nghal/Play-Store-App-Review-Analysis-EDA)Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Problem Statement: Analyzing App Performance and User Sentiment in the Google Play Store
#
# Objective: The objective of this project is to conduct exploratory data analysis (EDA) on two datasets related to the Google Play Store. The analysis aims to gain insights into app performance, user sentiment, and the relationship between app characteristics and user reviews.
#
# Datasets:
# 1. Dataset 1: Google Play Store Apps Details
#    - Link: [Dataset 1](https://drive.google.com/file/d/1CKnRIV0_MrzGzc2uDepxMs0uVUVB0XMG/view?usp=sharing)
#    - Description: This dataset contains details of various applications available on the Google Play Store. It includes features such as app name, category, rating, reviews, size, installs, price, etc.
#
# 2. Dataset 2: User Reviews
#    - Link: [Dataset 2](https://drive.google.com/file/d/1LwCUETIiQZeaOgB2MKz5yjJ7n6Aswwb-/view?usp=sharing)
#    - Description: This dataset contains user reviews for different apps on the Google Play Store. It includes information such as the text of the review, sentiment (positive, negative, or neutral), sentiment polarity, and sentiment subjectivity.
#
# Tasks:
# 1. Data Cleaning and Preprocessing: Perform necessary data cleaning steps, handle missing values, and preprocess the data to ensure its quality and suitability for analysis.
# 2. App Performance Analysis: Explore the dataset to understand app performance metrics such as ratings, reviews, installs, and pricing. Identify trends, popular categories, and factors that contribute to app success.
# 3. User Sentiment Analysis: Analyze the user reviews dataset to gain insights into user sentiment towards different apps. Investigate the distribution of sentiments, identify common positive and negative sentiments, and explore the relationship between sentiment and app characteristics.
# 4. Correlation and Insights: Investigate correlations between app performance metrics, user sentiment, and other relevant features. Discover meaningful patterns, relationships, or insights that can provide valuable recommendations or suggestions for app developers or stakeholders.
# 5. Data Visualization: Utilize appropriate visualizations (e.g., bar charts, scatter plots, heatmaps) to effectively present the findings and communicate insights.
#
# Deliverables:
# - Exploratory Data Analysis report summarizing the key findings, insights, and visualizations.
# - Visualizations and plots to support the analysis.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
#import library
import pandas as pd # for data processing
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool
from datetime import datetime
# plotly
import plotly 
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import warnings
#sns.set(font_scale=1.5)  set the font scale for seaborn plots
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# loading csv File
file_path = '/content/drive/MyDrive/Play Store Data.csv'
playstore_df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Display first 4 rows
print(playstore_df.head(4))

# Display last 4 rows
print(playstore_df.tail(4))
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of rows:", playstore_df.shape[0])
print("Number of columns:", playstore_df.shape[1])
# Out:
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
playstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = playstore_df.duplicated().sum()

print("Number of duplicate rows in the dataset:", duplicate_count)
# Out:
# Number of duplicate rows in the dataset: 483

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values_count = playstore_df.isnull().sum()

print("Number of missing values in each column:")
print(missing_values_count)
# Out:
# Number of missing values in each column:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Visualizing the missing values
# Generate a heatmap of missing values
sns.heatmap(playstore_df.isnull(), cmap='viridis')

# Set plot title
plt.title('Missing Values Heatmap')

# Display the plot
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In the dataset, we observe that the Rating column has 1474 null values, accounting for approximately 13.60% of the data. Additionally, the Type column has 1 null value, which makes up about 0.01% of the data. Similarly, the Content_Rating column has 1 null value, contributing approximately 0.01% of the data. We also find that the Current_Ver column has 8 null values, representing around 0.07% of the data, while the Android_Ver column has 3 null values, accounting for approximately 0.03% of the data. Furthermore, the dataset contains 483 duplicate rows.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns = playstore_df.columns
print(columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Dataset Describe
dataset_summary = playstore_df.describe()
print(dataset_summary)
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# # Variables Description

# %%
variables_description = playstore_df.dtypes
print(variables_description)
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in playstore_df.columns:
    unique_values = playstore_df[column].unique()
    print(f"Unique values for {column}: {unique_values}")
# Out:
# Unique values for App: ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# Unique values for Category: ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# Unique values for Rating: [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
